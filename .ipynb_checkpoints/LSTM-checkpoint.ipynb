# %%
import pandas as pd
import numpy as np
import math
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv(os.getcwd() + '/Datasets/Ontario/Hourly_Electricity_Ontario.csv')
df['time'] = pd.to_datetime(df['time'])
df = df[df['time'].dt.year != 2003]
df
# Out:
#                       time  precipitation  temperature  irradiance_surface  \
# 8760   2004-01-01 00:00:00         0.0020       -1.041              0.0000
# 8761   2004-01-01 01:00:00         0.0014       -1.359              0.0000
# 8762   2004-01-01 02:00:00         0.0012       -1.513              0.0000
# 8763   2004-01-01 03:00:00         0.0012       -1.673              0.0000
# 8764   2004-01-01 04:00:00         0.0012       -1.757              0.0000
# ...                    ...            ...          ...                 ...
# 122731 2016-12-31 19:00:00         0.1642        0.551             65.7947
# 122732 2016-12-31 20:00:00         0.1857        0.455             29.8108
# 122733 2016-12-31 21:00:00         0.2322        0.180              4.8503
# 122734 2016-12-31 22:00:00         0.2462       -0.047              0.0047
# 122735 2016-12-31 23:00:00         0.2163       -0.166              0.0000
#
#         irradiance_toa  snowfall  snow_depth  cloud_cover  air_density  \
# 8760            0.0000    0.0013     17.2316       0.1322       1.2664
# 8761            0.0000    0.0013     17.2312       0.1324       1.2690
# 8762            0.0000    0.0011     17.2309       0.1482       1.2707
# 8763            0.0000    0.0010     17.2305       0.1704       1.2724
# 8764            0.0000    0.0011     17.2302       0.2042       1.2738
# ...                ...       ...         ...          ...          ...
# 122731        394.8765    0.0845     16.9569       0.9761       1.2408
# 122732        238.0150    0.0863     16.9597       0.9729       1.2407
# 122733         52.9368    0.1055     16.9680       0.9628       1.2417
# 122734          0.0378    0.1173     16.9865       0.9353       1.2430
# 122735          0.0000    0.1002     17.0087       0.8799       1.2441
#
#         Total Energy Use from Electricity (MW)
# 8760                                     14703
# 8761                                     14130
# 8762                                     13575
# 8763                                     13280
# 8764                                     13219
# ...                                        ...
# 122731                                   16260
# 122732                                   15658
# 122733                                   15195
# 122734                                   14758
# 122735                                   14153
#
# [113976 rows x 10 columns]

# %%
df = df.drop(columns=["precipitation", "temperature", "irradiance_surface", "irradiance_toa", "snowfall", "snow_depth", "cloud_cover", "air_density"])

# %%
df = df.rename(columns={"Total Energy Use from Electricity (MW)": "Consumption", "time": "DateTime"})
df["Year"] = pd.to_datetime(df["DateTime"]).dt.year
df["Month"] = pd.to_datetime(df["DateTime"]).dt.month
df["Date"] = pd.to_datetime(df["DateTime"]).dt.date
df["Time"] = pd.to_datetime(df["DateTime"]).dt.time
df = df.set_index("DateTime")
df.index = pd.to_datetime(df.index)

# %%
df = df[['Time', "Date", "Month", "Year", "Consumption"]]
df
# Out:
#                          Time        Date  Month  Year  Consumption
# DateTime
# 2004-01-01 00:00:00  00:00:00  2004-01-01      1  2004        14703
# 2004-01-01 01:00:00  01:00:00  2004-01-01      1  2004        14130
# 2004-01-01 02:00:00  02:00:00  2004-01-01      1  2004        13575
# 2004-01-01 03:00:00  03:00:00  2004-01-01      1  2004        13280
# 2004-01-01 04:00:00  04:00:00  2004-01-01      1  2004        13219
# ...                       ...         ...    ...   ...          ...
# 2016-12-31 19:00:00  19:00:00  2016-12-31     12  2016        16260
# 2016-12-31 20:00:00  20:00:00  2016-12-31     12  2016        15658
# 2016-12-31 21:00:00  21:00:00  2016-12-31     12  2016        15195
# 2016-12-31 22:00:00  22:00:00  2016-12-31     12  2016        14758
# 2016-12-31 23:00:00  23:00:00  2016-12-31     12  2016        14153
#
# [113976 rows x 5 columns]

# %%
# Downsampling from hours to days
df_day = df.drop(columns=["Month", "Year"])
df_day = df_day.resample("D").sum()
# Out:
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_13458/1198080928.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_day = df_day.resample("D").sum()

# %%
df_day
# Out:
#             Consumption
# DateTime
# 2004-01-01       363449
# 2004-01-02       392163
# 2004-01-03       377787
# 2004-01-04       392135
# 2004-01-05       460254
# ...                 ...
# 2016-12-27       349744
# 2016-12-28       370750
# 2016-12-29       370212
# 2016-12-30       368597
# 2016-12-31       356693
#
# [4749 rows x 1 columns]

# %% [markdown]
# ## Normalizing the data

# %%
Y = np.array(df_day["Consumption"])
Y
# Out:
# array([363449, 392163, 377787, ..., 370212, 368597, 356693])

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
Y = scaler.fit_transform(Y.reshape(-1,1))
Y
# Out:
# array([[0.28377331],
#        [0.38584866],
#        [0.33474344],
#        ...,
#        [0.30781509],
#        [0.30207393],
#        [0.25975642]])

# %%
def create_io_pair(data, k=1):
    """
        k: time step
        return input-output pair from given dataset
    """
    dataX, dataY = [], []
    for i in range(len(data) - k - 1):
        dataX.append(data[i:(i + k), 0])
        dataY.append(data[i + k, 0])
    return np.array(dataX), np.array(dataY)

# %%
training_size = math.ceil(len(Y)*.80)
testing_size = len(Y) - training_size
validation_size = int(training_size*.20)
training_data, testing_data, validation_data = Y[0:training_size-validation_size, :], Y[training_size:len(Y), :1], Y[len(Y)-testing_size-validation_size:len(Y)-testing_size, :1]

# %%
training_size
# Out:
# 3800

# %%
k = 100 # step
X_train, y_train = create_io_pair(training_data, k=k)
X_test, y_test = create_io_pair(testing_data, k=k)
X_validation, y_validation = create_io_pair(validation_data, k=k)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_validation = X_validation.reshape(X_validation.shape[0], X_validation.shape[1], 1)

# %%
X_train.shape
# Out:
# (2939, 100, 1)

# %%
X_test.shape
# Out:
# (848, 100, 1)

# %%
X_validation.shape
# Out:
# (659, 100, 1)

# %%
# using sequential to build LSTM model
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_absolute_error')

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  lstm_2 (LSTM)               (None, 100, 50)           20200
#
#  dropout_2 (Dropout)         (None, 100, 50)           0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = regressor.fit(X_train, y_train, epochs = 60, batch_size = 64)
# Out:
# Epoch 1/60
# 46/46 [==============================] - 14s 114ms/step - loss: 0.1374
# Epoch 2/60
# 46/46 [==============================] - 6s 125ms/step - loss: 0.1013
# Epoch 3/60
# 46/46 [==============================] - 6s 121ms/step - loss: 0.0978
# Epoch 4/60
# 46/46 [==============================] - 6s 127ms/step - loss: 0.
# Epoch 40/60
# 46/46 [==============================] - 7s 149ms/step - loss: 0.0869
# Epoch 41/60
# 46/46 [==============================] - 7s 147ms/step - loss: 0.0865
# Epoch 42/60
# 46/46 [==============================] - 8s 171ms/step - loss: 0.0864
# Epoch 43/60
# 46/46 [==============================] - 13s 273ms/step - loss: 0.0857
# Epoch 44/60
# 46/46 [==============================] - 8s 179ms/step - loss: 0.0861
# Epoch 45/60
# 46/46 [==============================] - 7s 153ms/step - loss: 0.0865
# Epoch 46/60
# 46/46 [==============================] - 8s 181ms/step - loss: 0.0863
# Epoch 47/60
# 46/46 [==============================] - 7s 161ms/step - loss: 0.0862
# Epoch 48/60
# 46/46 [==============================] - 8s 172ms/step - loss: 0.0859
# Epoch 49/60
# 46/46 [==============================] - 8s 168ms/step - loss: 0.0869
# Epoch 50/60
# 46/46 [==============================] - 8s 184ms/step - loss: 0.0853
# Epoch 51/60
# 46/46 [==============================] - 7s 148ms/step - loss: 0.0857
# Epoch 52/60
# 46/46 [==============================] - 8s 168ms/step - loss: 0.0859
# Epoch 53/60
# 46/46 [==============================] - 7s 151ms/step - loss: 0.0856
# Epoch 54/60
# 46/46 [==============================] - 7s 158ms/step - loss: 0.0846
# Epoch 55/60
# 46/46 [==============================] - 7s 152ms/step - loss: 0.0866
# Epoch 56/60
# 46/46 [==============================] - 7s 149ms/step - loss: 0.0858
# Epoch 57/60
# 46/46 [==============================] - 7s 150ms/step - loss: 0.0857
# Epoch 58/60
# 46/46 [==============================] - 7s 157ms/step - loss: 0.0854
# Epoch 59/60
# 46/46 [==============================] - 8s 168ms/step - loss: 0.0855
# Epoch 60/60
# 46/46 [==============================] - 7s 147ms/step - loss: 0.0870

# %%
y_pred = regressor.predict(X_test)
# Out:
# 27/27 [==============================] - 1s 28ms/step

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 0.08179668205953752

# %%
actual = scaler.inverse_transform(y_pred)
actual
# Out:
# array([[391347.62],
#        [395010.28],
#        [398805.5 ],
#        [400227.25],
#        [399117.16],
#        [396251.06],
#        [392810.47],
#        [389487.88],
#        [386382.7 ],
#        [383097.66],
#        [379149.03],
#        [374638.75],
#        [370016.4 ],
#        [365832.53],
#        [362503.4 ],
#        [360163.94],
#        [358513.22],
#        [357009.9 ],
#        [355365.38],
#        [353688.06],
#        [352321.44],
#        [351624.9 ],
#        [351794.6 ],
#        [352560.72],
#        [353283.9 ],
#        [353733.6 ],
#        [354126.25],
#        [354738.72],
#        [355744.66],
#        [357125.22],
#        [358371.66],
#        [358719.66],
#        [357920.28],
#        [356313.16],
#        [354480.56],
#        [353020.84],
#        [352397.3 ],
#        [352560.62],
#        [352864.16],
#        [352602.44],
#        [351629.62],
#        [350463.06],
#        [349873.22],
#        [350352.16],
#        [351662.56],
#        [353031.97],
#        [354054.28],
#        [354934.66],
#        [356032.84],
#        [357525.25],
#        [359292.88],
#        [360751.6 ],
#        [361304.5 ],
#        [360909.72],
#        [359994.34],
#        [359150.47],
#        [358956.6 ],
#        [359815.7 ],
#        [361596.97],
#        [363602.38],
#        [365351.16],
#        [366722.38],
#        [367802.12],
#        [368868.1 ],
#        [370213.1 ],
#        [371743.72],
#        [372980.22],
#        [373787.78],
#        [374170.56],
#        [374454.16],
#        [375268.3 ],
#        [377075.25],
#        [379570.38],
#        [382106.3 ],
#        [384699.9 ],
#        [387778.62],
#        [391778.12],
#        [396547.22],
#        [401571.22],
#        [405427.88],
#        [406770.47],
#        [405929.94],
#        [404039.97],
#        [402289.3 ],
#        [401551.2 ],
#        [402319.38],
#        [403717.72],
#        [404235.62],
#        [404053.97],
#        [404258.8 ],
#        [405307.84],
#        [407314.06],
#        [409933.94],
#        [411640.97],
#        [411759.22],
#        [411101.12],
#        [410209.12],
#        [409640.53],
#        [409987.  ],
#        [411060.28],
#        [411806.38],
#        [411369.16],
#        [410214.66],
#        [408907.38],
#        [407798.16],
#        [407402.25],
#        [407847.9 ],
#        [408372.97],
#        [408155.7 ],
#        [407482.97],
#        [406455.  ],
#        [404316.8 ],
#        [400357.75],
#        [394538.38],
#        [387303.9 ],
#        [379387.97],
#        [371935.34],
#        [366393.72],
#        [363967.4 ],
#        [364764.3 ],
#        [367992.2 ],
#        [372645.8 ],
#        [377493.5 ],
#        [382581.1 ],
#        [388542.4 ],
#        [395888.53],
#        [404538.56],
#        [412900.  ],
#        [419216.12],
#        [422468.4 ],
#        [423724.44],
#        [424693.8 ],
#        [426211.72],
#        [428222.62],
#        [430041.1 ],
#        [430887.62],
#        [429631.78],
#        [427568.62],
#        [425889.66],
#        [425496.53],
#        [426090.72],
#        [426721.88],
#        [426309.28],
#        [424550.28],
#        [423038.44],
#        [422594.7 ],
#        [423339.28],
#        [425033.2 ],
#        [427108.66],
#        [428599.12],
#        [428933.06],
#        [429338.62],
#        [430069.9 ],
#        [430915.75],
#        [431854.22],
#        [432563.3 ],
#        [432023.1 ],
#        [430494.  ],
#        [429365.6 ],
#        [428747.53],
#        [428807.22],
#        [429524.1 ],
#        [431222.6 ],
#        [432384.4 ],
#        [433251.56],
#        [433956.66],
#        [434970.16],
#        [436277.38],
#        [438098.12],
#        [440428.3 ],
#        [441644.22],
#        [440956.38],
#        [440230.53],
#        [439918.4 ],
#        [439789.3 ],
#        [440233.34],
#        [440763.78],
#        [439897.84],
#        [437354.47],
#        [434022.34],
#        [431008.03],
#        [428272.88],
#        [426612.34],
#        [426073.44],
#        [425297.94],
#        [423113.5 ],
#        [419777.44],
#        [415673.16],
#        [410988.94],
#        [406258.53],
#        [401921.56],
#        [397842.2 ],
#        [393750.03],
#        [389862.8 ],
#        [386480.47],
#        [384031.6 ],
#        [382789.3 ],
#        [382511.66],
#        [382455.97],
#        [382111.16],
#        [381854.3 ],
#        [382027.34],
#        [382797.  ],
#        [384114.56],
#        [385771.84],
#        [387094.53],
#        [387076.2 ],
#        [385914.3 ],
#        [384103.34],
#        [382150.5 ],
#        [380309.84],
#        [378158.06],
#        [375311.  ],
#        [371724.75],
#        [367902.16],
#        [364634.44],
#        [362900.06],
#        [363449.28],
#        [366037.22],
#        [369196.84],
#        [371152.75],
#        [371170.4 ],
#        [369356.8 ],
#        [366218.12],
#        [362401.7 ],
#        [358502.38],
#        [354720.75],
#        [350877.72],
#        [346968.75],
#        [343447.12],
#        [340956.5 ],
#        [340155.94],
#        [341388.38],
#        [344129.25],
#        [347096.28],
#        [349300.38],
#        [350415.1 ],
#        [350495.47],
#        [349782.34],
#        [348568.84],
#        [346960.62],
#        [344813.28],
#        [342098.03],
#        [339197.06],
#        [336705.56],
#        [335207.97],
#        [335155.2 ],
#        [336682.66],
#        [339432.  ],
#        [342879.9 ],
#        [346556.9 ],
#        [349927.34],
#        [352514.  ],
#        [354041.56],
#        [354325.06],
#        [353193.38],
#        [350704.7 ],
#        [347343.66],
#        [343871.78],
#        [341003.7 ],
#        [339224.88],
#        [338521.88],
#        [338356.28],
#        [338355.28],
#        [339015.12],
#        [341405.8 ],
#        [346151.53],
#        [352801.78],
#        [359888.62],
#        [365299.44],
#        [367943.38],
#        [367892.9 ],
#        [365779.6 ],
#        [362518.7 ],
#        [359192.06],
#        [356421.44],
#        [354088.8 ],
#        [352128.12],
#        [350977.22],
#        [351187.56],
#        [353036.47],
#        [356271.4 ],
#        [359823.78],
#        [362429.6 ],
#        [363888.4 ],
#        [364930.5 ],
#        [366124.53],
#        [367775.78],
#        [369667.94],
#        [370952.9 ],
#        [371100.38],
#        [370539.9 ],
#        [370157.6 ],
#        [370561.72],
#        [371929.3 ],
#        [373899.47],
#        [375316.78],
#        [375015.44],
#        [372839.22],
#        [369363.6 ],
#        [365225.06],
#        [360993.44],
#        [357125.03],
#        [353834.03],
#        [351221.72],
#        [349847.9 ],
#        [350850.2 ],
#        [354597.12],
#        [360203.66],
#        [366373.1 ],
#        [371838.94],
#        [375916.47],
#        [379217.  ],
#        [382612.03],
#        [385611.72],
#        [387604.06],
#        [388353.2 ],
#        [388349.97],
#        [388620.53],
#        [390136.4 ],
#        [392983.06],
#        [396126.5 ],
#        [398640.06],
#        [400354.66],
#        [401272.94],
#        [401641.47],
#        [402934.78],
#        [406588.47],
#        [413190.1 ],
#        [421303.66],
#        [427904.34],
#        [429821.72],
#        [427060.88],
#        [420831.3 ],
#        [412886.06],
#        [404441.56],
#        [396563.9 ],
#        [390145.94],
#        [385285.75],
#        [381585.97],
#        [379024.16],
#        [377898.25],
#        [378095.3 ],
#        [379248.22],
#        [381301.8 ],
#        [384105.25],
#        [387513.84],
#        [392461.16],
#        [399038.25],
#        [406632.12],
#        [413594.97],
#        [417139.16],
#        [416213.75],
#        [411499.03],
#        [404695.5 ],
#        [396996.75],
#        [389444.53],
#        [382877.72],
#        [377844.4 ],
#        [374352.8 ],
#        [372188.97],
#        [371929.8 ],
#        [374676.88],
#        [381358.66],
#        [391758.78],
#        [403015.84],
#        [411732.8 ],
#        [416970.06],
#        [419748.6 ],
#        [421883.53],
#        [423083.78],
#        [422183.8 ],
#        [418906.12],
#        [412811.5 ],
#        [404290.53],
#        [394371.9 ],
#        [384347.5 ],
#        [375854.53],
#        [370697.97],
#        [369971.66],
#        [372708.75],
#        [376077.4 ],
#        [378106.7 ],
#        [378244.5 ],
#        [376799.94],
#        [374470.8 ],
#        [371838.2 ],
#        [368896.34],
#        [365393.62],
#        [361604.6 ],
#        [358239.22],
#        [355774.28],
#        [354158.2 ],
#        [353059.06],
#        [352020.03],
#        [350615.8 ],
#        [348826.4 ],
#        [347079.3 ],
#        [345888.28],
#        [345565.3 ],
#        [346162.16],
#        [347236.94],
#        [347886.2 ],
#        [347285.22],
#        [345242.3 ],
#        [342294.62],
#        [339343.88],
#        [337322.97],
#        [336815.8 ],
#        [337793.9 ],
#        [339933.12],
#        [342910.7 ],
#        [346422.94],
#        [350147.38],
#        [353721.22],
#        [356669.2 ],
#        [358506.  ],
#        [359206.22],
#        [359218.  ],
#        [359233.62],
#        [359780.22],
#        [361009.9 ],
#        [362581.22],
#        [363733.1 ],
#        [364042.75],
#        [363592.16],
#        [362713.94],
#        [361777.25],
#        [361021.7 ],
#        [360317.75],
#        [359277.38],
#        [357803.72],
#        [356330.9 ],
#        [355449.78],
#        [355571.84],
#        [356774.94],
#        [358640.75],
#        [360290.7 ],
#        [361168.8 ],
#        [361295.03],
#        [360987.03],
#        [360552.44],
#        [360237.94],
#        [360185.47],
#        [360342.28],
#        [360934.44],
#        [362489.03],
#        [365217.34],
#        [368709.28],
#        [372249.62],
#        [375123.62],
#        [376919.22],
#        [377982.4 ],
#        [378983.38],
#        [380331.4 ],
#        [382104.84],
#        [384113.84],
#        [385580.7 ],
#        [385834.6 ],
#        [385221.34],
#        [384417.22],
#        [383796.22],
#        [383411.53],
#        [383026.1 ],
#        [382285.75],
#        [380897.25],
#        [379058.28],
#        [377315.6 ],
#        [376400.47],
#        [376682.56],
#        [378144.53],
#        [380276.78],
#        [382196.72],
#        [383559.38],
#        [384263.7 ],
#        [384155.9 ],
#        [382575.2 ],
#        [379080.47],
#        [373767.97],
#        [367198.94],
#        [360371.7 ],
#        [354623.88],
#        [351249.34],
#        [350820.66],
#        [352735.9 ],
#        [355801.6 ],
#        [359042.25],
#        [362644.84],
#        [367578.2 ],
#        [374039.6 ],
#        [381284.1 ],
#        [388185.6 ],
#        [393107.  ],
#        [395332.44],
#        [396023.38],
#        [396611.2 ],
#        [398199.03],
#        [401323.72],
#        [405326.22],
#        [408546.6 ],
#        [410188.06],
#        [411203.03],
#        [412650.4 ],
#        [414884.28],
#        [417548.06],
#        [419931.88],
#        [420788.88],
#        [419875.88],
#        [417759.7 ],
#        [414911.1 ],
#        [411950.28],
#        [409555.94],
#        [408145.1 ],
#        [407044.94],
#        [405273.3 ],
#        [402820.9 ],
#        [400144.75],
#        [397614.44],
#        [395605.78],
#        [394396.03],
#        [393529.53],
#        [392325.2 ],
#        [391026.84],
#        [390254.44],
#        [390586.75],
#        [392738.66],
#        [396801.1 ],
#        [402236.94],
#        [407747.3 ],
#        [412266.12],
#        [415367.25],
#        [416948.78],
#        [417359.94],
#        [416612.16],
#        [413762.66],
#        [408971.34],
#        [403477.28],
#        [398448.5 ],
#        [395149.97],
#        [394256.4 ],
#        [395673.8 ],
#        [397814.62],
#        [398743.7 ],
#        [398338.9 ],
#        [397642.97],
#        [397640.72],
#        [398876.44],
#        [400977.34],
#        [402585.66],
#        [402482.97],
#        [400645.2 ],
#        [397325.38],
#        [392932.44],
#        [388173.5 ],
#        [383569.88],
#        [379119.1 ],
#        [374545.97],
#        [370082.44],
#        [366308.1 ],
#        [363692.44],
#        [362327.9 ],
#        [362015.94],
#        [362198.12],
#        [362188.6 ],
#        [361852.1 ],
#        [361571.3 ],
#        [361856.1 ],
#        [363267.34],
#        [365365.78],
#        [367052.44],
#        [367108.22],
#        [365357.9 ],
#        [362417.75],
#        [359139.56],
#        [356331.78],
#        [354537.53],
#        [353797.75],
#        [353848.28],
#        [354664.47],
#        [356470.8 ],
#        [359474.6 ],
#        [363504.3 ],
#        [368005.66],
#        [371915.94],
#        [374474.47],
#        [375769.38],
#        [376180.72],
#        [376053.9 ],
#        [375508.3 ],
#        [374423.72],
#        [372377.53],
#        [368997.9 ],
#        [364419.84],
#        [359188.28],
#        [353965.  ],
#        [349396.2 ],
#        [345998.28],
#        [343818.56],
#        [342362.1 ],
#        [341191.56],
#        [340382.78],
#        [340243.75],
#        [340910.56],
#        [342235.7 ],
#        [343625.1 ],
#        [344317.72],
#        [344008.  ],
#        [342916.75],
#        [341458.16],
#        [340021.12],
#        [338828.25],
#        [337798.16],
#        [336525.16],
#        [334661.6 ],
#        [332336.47],
#        [329968.34],
#        [328047.47],
#        [327003.94],
#        [326941.56],
#        [327464.22],
#        [328077.22],
#        [328655.88],
#        [329325.97],
#        [330230.16],
#        [331432.12],
#        [332690.3 ],
#        [333383.06],
#        [332880.9 ],
#        [331057.66],
#        [328707.8 ],
#        [327352.  ],
#        [328717.75],
#        [334051.3 ],
#        [343157.6 ],
#        [354776.06],
#        [366848.25],
#        [376902.97],
#        [383994.  ],
#        [388177.53],
#        [389478.3 ],
#        [388101.94],
#        [384827.75],
#        [380464.8 ],
#        [375635.34],
#        [370816.34],
#        [366430.84],
#        [362880.1 ],
#        [360179.28],
#        [358092.78],
#        [356543.06],
#        [355644.84],
#        [355694.12],
#        [357174.88],
#        [360352.53],
#        [365015.03],
#        [371412.9 ],
#        [378655.7 ],
#        [385216.6 ],
#        [389893.66],
#        [392490.72],
#        [393187.4 ],
#        [392800.47],
#        [393246.38],
#        [394758.53],
#        [396544.12],
#        [397877.75],
#        [397264.88],
#        [394010.8 ],
#        [388439.03],
#        [381850.22],
#        [376259.88],
#        [374170.34],
#        [377767.12],
#        [386735.12],
#        [396649.28],
#        [403511.1 ],
#        [407109.1 ],
#        [408787.2 ],
#        [410887.9 ],
#        [414036.56],
#        [416941.56],
#        [416949.16],
#        [413654.1 ],
#        [409207.4 ],
#        [404463.5 ],
#        [400326.75],
#        [398275.88],
#        [400117.66],
#        [405527.44],
#        [411515.1 ],
#        [417337.97],
#        [422268.62],
#        [426370.34],
#        [429809.03],
#        [431428.4 ],
#        [429458.25],
#        [424222.66],
#        [417223.03],
#        [410592.88],
#        [406295.2 ],
#        [406156.72],
#        [410887.28],
#        [416984.97],
#        [420898.1 ],
#        [422590.72],
#        [423025.12],
#        [424275.62],
#        [427707.28],
#        [433456.62],
#        [437976.97],
#        [438964.16],
#        [437668.94],
#        [434916.56],
#        [431158.84],
#        [427830.75],
#        [425776.7 ],
#        [424877.78],
#        [423412.28],
#        [420610.28],
#        [416907.2 ],
#        [413465.22],
#        [411950.06],
#        [412810.97],
#        [414191.38],
#        [415288.78],
#        [416173.1 ],
#        [417044.25],
#        [418032.84],
#        [417599.  ],
#        [414937.47],
#        [409522.38],
#        [401722.2 ],
#        [392517.8 ],
#        [383897.47],
#        [378839.47],
#        [380241.72],
#        [388094.2 ],
#        [398056.8 ],
#        [404731.7 ],
#        [406938.78],
#        [405535.1 ],
#        [401594.5 ],
#        [395923.75],
#        [389360.  ],
#        [382608.3 ],
#        [376267.6 ],
#        [371273.62],
#        [368700.28],
#        [368933.03],
#        [371686.4 ],
#        [375765.47],
#        [378815.72],
#        [379143.8 ],
#        [376741.2 ],
#        [372287.94],
#        [366717.44],
#        [360971.53],
#        [355808.03],
#        [351580.88],
#        [348215.53],
#        [345584.94],
#        [343758.22],
#        [342839.53],
#        [342889.6 ],
#        [343867.72],
#        [345258.97],
#        [346111.28],
#        [345594.9 ],
#        [343512.03],
#        [340376.94],
#        [337052.88],
#        [334421.94],
#        [332977.62],
#        [332553.38],
#        [332834.22],
#        [333837.5 ],
#        [335655.38],
#        [338203.94],
#        [341226.25],
#        [344139.56],
#        [346169.12],
#        [346943.75],
#        [346773.  ],
#        [346404.7 ],
#        [346792.06],
#        [348651.97],
#        [351704.62],
#        [355002.94],
#        [357845.34],
#        [359980.6 ],
#        [361452.97],
#        [362436.62],
#        [363055.22],
#        [363107.7 ],
#        [362210.72],
#        [360349.38],
#        [357984.9 ],
#        [355785.25],
#        [354338.38],
#        [353930.16],
#        [354351.88],
#        [354890.84],
#        [354991.88],
#        [354688.25],
#        [354416.8 ],
#        [354642.8 ],
#        [355486.6 ],
#        [356601.53],
#        [357612.75],
#        [358740.47],
#        [360653.12],
#        [363971.84],
#        [368825.78],
#        [374511.53],
#        [379512.4 ],
#        [382544.1 ],
#        [383519.  ],
#        [382903.5 ],
#        [381400.56],
#        [379672.62],
#        [378270.47],
#        [377313.7 ],
#        [376620.22],
#        [376361.  ],
#        [376847.72],
#        [378230.72],
#        [380540.78],
#        [383686.88],
#        [387115.6 ],
#        [390257.75],
#        [393108.62],
#        [395863.53],
#        [398854.47],
#        [402568.53],
#        [407006.38],
#        [410928.28],
#        [413319.22],
#        [415053.3 ],
#        [416265.78],
#        [416808.28],
#        [416515.6 ],
#        [414951.03],
#        [411552.03],
#        [406086.84],
#        [399108.28],
#        [391372.16],
#        [383907.28],
#        [377742.9 ]], dtype=float32)

# %%
plt.figure(figsize=(12,7))
plt.title('LSTM Model')
plt.xlabel('Step')
plt.ylabel('Total Energy Use from Electricity (MWh)')
plt.plot(y_test, color="blue")
plt.plot(y_pred, color="red")
plt.show()

# %%
df_results = pd.DataFrame()
df_results["Predictions"] = y_pred.tolist()
df_results["Actuals"] = y_test.tolist()

df_results
# Out:
#                Predictions                Actuals
# 0     [0.3829501271247864]   [0.5367505385670914]
# 1     [0.3959704637527466]  [0.25872905276180047]
# 2     [0.4094621539115906]  [0.14739674797904012]
# 3     [0.4145162105560303]   [0.2974525598822617]
# 4      [0.410569965839386]   [0.3457991766855548]
# ..                     ...                    ...
# 843   [0.4353465437889099]  [0.21982069093003243]
# 844  [0.41053852438926697]  [0.23505343012136404]
# 845   [0.3830372095108032]    [0.309727623692686]
# 846  [0.35650041699409485]  [0.30781508841032057]
# 847  [0.33458662033081055]  [0.30207392766492935]
#
# [848 rows x 2 columns]

# %%
def create_model(units=50, dropout_rate=0.2, optimizer='adam'):
    model = Sequential()
    model.add(LSTM(units=units, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(units=units, return_sequences=True))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(units=units, return_sequences=True))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(units=units))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=1))
    model.compile(optimizer=optimizer, loss='mean_absolute_error')
    return model

# %%
keras_model = KerasRegressor(build_fn=create_model)

param_grid = {
    'units': [40, 50, 60],
    'dropout_rate': [0.1, 0.2, 0.3],
    'optimizer': ['adam', 'rmsprop'],
}

grid = GridSearchCV(estimator=keras_model, param_grid=param_grid, cv=3)
grid_result = grid.fit(X_train, y_train)
# Out:
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_824/1761965593.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasRegressor(build_fn=create_model)
# 62/62 [==============================] - 14s 82ms/step - loss: 0.1226
# 31/31 [==============================] - 3s 22ms/step - loss: 0.0995
# 62/62 [==============================] - 15s 86ms/step - loss: 0.1209
# 31/31 [==============================] - 2s 20ms/step - loss: 0.0935
# 62/62 [==============================] - 15s 82ms/step - loss: 0.1340
# 31/31 [==============================] - 2s 21ms/step - loss: 0.0850
# 62/62 [==============================] - 15s 89ms/step - loss: 0.1110
# 31/31 [==============================] - 3s 25ms/step - loss: 0.0985
# 62/62 [==============================] - 15s 85ms/step - loss: 0.1268
# 31/31 [==============================] - 2s 25ms/step - loss: 0.1023
# 62/62 [==============================] - 15s 86ms/step - loss: 0.1280
# 31/31 [==============================] - 2s 25ms/step - loss: 0.0899
# 62/62 [==============================] - 15s 98ms/step - loss: 0.1129
# 31/31 [==============================] - 3s 30ms/step - loss: 0.1076
