# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, RepeatedKFold,GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler
# Out:
# 2023-04-11 23:42:24.044900: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Pre-processing

# %%
df_hourly = pd.read_csv(os.getcwd() + '/Datasets/Ontario/Hourly_Electricity_Ontario.csv')

# %%
df_hourly['time'] = pd.to_datetime(df_hourly['time'])
df_hourly = df_hourly[df_hourly['time'].dt.year != 2003]
# Function to standardize a column using z-score
def standardize_column(column):
    mean = column.mean()
    std = column.std()
    return (column - mean) / std

# Select only the numeric columns
numeric_columns = df_hourly.select_dtypes(include=['number'])

# Standardize the numeric columns
standardized_numeric_columns = numeric_columns.apply(standardize_column)

# Replace the original numeric columns with the standardized columns
standardized_df_hourly = df_hourly.copy()
standardized_df_hourly.update(standardized_numeric_columns)
standardized_df_hourly
# Out:
#                       time  precipitation  temperature  irradiance_surface  \
# 8760   2004-01-01 00:00:00      -0.451903    -0.796244           -0.692273
# 8761   2004-01-01 01:00:00      -0.455072    -0.824607           -0.692273
# 8762   2004-01-01 02:00:00      -0.456129    -0.838342           -0.692273
# 8763   2004-01-01 03:00:00      -0.456129    -0.852613           -0.692273
# 8764   2004-01-01 04:00:00      -0.456129    -0.860105           -0.692273
# ...                    ...            ...          ...                 ...
# 122731 2016-12-31 19:00:00       0.404924    -0.654253           -0.424961
# 122732 2016-12-31 20:00:00       0.518499    -0.662815           -0.571157
# 122733 2016-12-31 21:00:00       0.764136    -0.687343           -0.672567
# 122734 2016-12-31 22:00:00       0.838092    -0.707589           -0.692254
# 122735 2016-12-31 23:00:00       0.680144    -0.718203           -0.692273
#
#         irradiance_toa  snowfall  snow_depth  cloud_cover  air_density  \
# 8760         -0.793046 -0.233383    1.306661    -1.333449     0.763748
# 8761         -0.793046 -0.233383    1.306611    -1.332801     0.812158
# 8762         -0.793046 -0.236296    1.306574    -1.281579     0.843811
# 8763         -0.793046 -0.237753    1.306524    -1.209609     0.875464
# 8764         -0.793046 -0.236296    1.306487    -1.100033     0.901531
# ...                ...       ...         ...          ...          ...
# 122731        0.213500  0.978395    1.272506     1.402390     0.287094
# 122732       -0.186342  1.004611    1.272854     1.392016     0.285232
# 122733       -0.658109  1.284252    1.273886     1.359273     0.303851
# 122734       -0.792950  1.456115    1.276186     1.270120     0.328056
# 122735       -0.793046  1.207059    1.278947     1.090519     0.348537
#
#         Total Energy Use from Electricity (MW)
# 8760                                 -0.692274
# 8761                                 -0.912585
# 8762                                 -1.125974
# 8763                                 -1.239397
# 8764                                 -1.262851
# ...                                        ...
# 122731                               -0.093631
# 122732                               -0.325091
# 122733                               -0.503108
# 122734                               -0.671128
# 122735                               -0.903741
#
# [113976 rows x 10 columns]

# %% [markdown]
# ### Add the season column
# - Spring: March 1st to May 31st
# - Summer: June 1st to August 31th
# - Fall: September 1st to November 30th
# - Winter: December 1st to February 28/29th
# - Based on https://www.durhamimmigration.ca/en/moving-to-durham-region/weather---four-seasons.aspx

# %%
def season(date):
    month = date.month
    season = None
    if month in [3, 4, 5]:
        season = 'spring'
    elif month in [6, 7, 8]:
        season = 'summer'
    elif month in [9, 10, 11]:
        season = 'fall'
    elif month in [12, 1, 2]:
        season = 'winter'
    return season

# Separate the time column into dates and hour column 
standardized_df_hourly['dates'] = pd.to_datetime(standardized_df_hourly['time']).dt.date
standardized_df_hourly['hour'] = pd.to_datetime(standardized_df_hourly['time']).dt.hour

# Create the season column
standardized_df_hourly['season'] = standardized_df_hourly.apply(lambda x: season(x['dates']), axis=1)

# %%
# Drop the time column and reorder the order of the columns
standardized_df_hourly.drop(columns='time')
standardized_df_hourly = standardized_df_hourly[['dates', 'hour', 'season', 'precipitation', 'temperature', 'irradiance_surface', 
           'irradiance_toa', 'snowfall', 'snow_depth', 'cloud_cover', 'air_density', 'Total Energy Use from Electricity (MW)']]

# %%
standardized_df_hourly
# Out:
#              dates  hour  season  precipitation  temperature  \
# 8760    2004-01-01     0  winter      -0.451903    -0.796244
# 8761    2004-01-01     1  winter      -0.455072    -0.824607
# 8762    2004-01-01     2  winter      -0.456129    -0.838342
# 8763    2004-01-01     3  winter      -0.456129    -0.852613
# 8764    2004-01-01     4  winter      -0.456129    -0.860105
# ...            ...   ...     ...            ...          ...
# 122731  2016-12-31    19  winter       0.404924    -0.654253
# 122732  2016-12-31    20  winter       0.518499    -0.662815
# 122733  2016-12-31    21  winter       0.764136    -0.687343
# 122734  2016-12-31    22  winter       0.838092    -0.707589
# 122735  2016-12-31    23  winter       0.680144    -0.718203
#
#         irradiance_surface  irradiance_toa  snowfall  snow_depth  cloud_cover  \
# 8760             -0.692273       -0.793046 -0.233383    1.306661    -1.333449
# 8761             -0.692273       -0.793046 -0.233383    1.306611    -1.332801
# 8762             -0.692273       -0.793046 -0.236296    1.306574    -1.281579
# 8763             -0.692273       -0.793046 -0.237753    1.306524    -1.209609
# 8764             -0.692273       -0.793046 -0.236296    1.306487    -1.100033
# ...                    ...             ...       ...         ...          ...
# 122731           -0.424961        0.213500  0.978395    1.272506     1.402390
# 122732           -0.571157       -0.186342  1.004611    1.272854     1.392016
# 122733           -0.672567       -0.658109  1.284252    1.273886     1.359273
# 122734           -0.692254       -0.792950  1.456115    1.276186     1.270120
# 122735           -0.692273       -0.793046  1.207059    1.278947     1.090519
#
#         air_density  Total Energy Use from Electricity (MW)
# 8760       0.763748                               -0.692274
# 8761       0.812158                               -0.912585
# 8762       0.843811                               -1.125974
# 8763       0.875464                               -1.239397
# 8764       0.901531                               -1.262851
# ...             ...                                     ...
# 122731     0.287094                               -0.093631
# 122732     0.285232                               -0.325091
# 122733     0.303851                               -0.503108
# 122734     0.328056                               -0.671128
# 122735     0.348537                               -0.903741
#
# [113976 rows x 12 columns]

# %%
standardized_df_hourly['season'].value_counts()
# Out:
# summer    28704
# spring    28691
# fall      28405
# winter    28176
# Name: season, dtype: int64

# %%
standardized_df_hourly['Total Energy Use from Electricity (MW)'].max()
# Out:
# 4.037664181256791

# %%
standardized_df_hourly['Total Energy Use from Electricity (MW)'].mean()
# Out:
# 7.979703637370395e-18

# %%
standardized_df_hourly['Total Energy Use from Electricity (MW)'].min() ## too low
# Out:
# -2.323261308512943

# %%
standardized_df_hourly.isnull().sum() # no Nan cell
# Out:
# dates                                     0
# hour                                      0
# season                                    0
# precipitation                             0
# temperature                               0
# irradiance_surface                        0
# irradiance_toa                            0
# snowfall                                  0
# snow_depth                                0
# cloud_cover                               0
# air_density                               0
# Total Energy Use from Electricity (MW)    0
# dtype: int64

# %% [markdown]
# ### Rule for merging hour -> daily
# - max temp,
# - max snow depth (not reasonable)
# - max snowfall
# - max precip
# - max irradiance
# - max cloud coverage
# - max air density
# - sum all energy

# %%
df_daily = pd.read_csv(os.getcwd() + '/Datasets/Ontario/Daily_Electricity_Ontario.csv')

# %%
df_daily['time'] = pd.to_datetime(df_daily['time']).dt.date
df_daily['time'] = pd.to_datetime(df_daily['time'], format='%Y/%m/%d')
df_daily = df_daily[df_daily['time'].dt.year != 2003]
df_daily
# Out:
#            time  snow_depth  Total Energy Use from Electricity (MW)  \
# 365  2004-01-01     17.2316                                  363449
# 366  2004-01-02     17.2797                                  392163
# 367  2004-01-03     17.3078                                  377787
# 368  2004-01-04     17.3005                                  392135
# 369  2004-01-05     17.3234                                  460254
# ...         ...         ...                                     ...
# 5109 2016-12-27     17.1246                                  349744
# 5110 2016-12-28     16.8999                                  370750
# 5111 2016-12-29     16.9279                                  370212
# 5112 2016-12-30     16.9282                                  368597
# 5113 2016-12-31     17.0087                                  356693
#
#       temperature  irradiance_surface  irradiance_toa  snowfall  cloud_cover  \
# 365         0.335            311.1307        542.9119    0.0608       0.9669
# 366         3.126            202.3642        544.8137    1.0279       0.9959
# 367         5.863            167.0140        546.8158    0.6193       0.9964
# 368         2.157            183.1127        548.9446    0.3873       0.9734
# 369        -3.564            179.3832        551.3384    2.6992       0.9688
# ...           ...                 ...             ...       ...          ...
# 5109        6.067            202.2915        536.8441    0.5069       0.8070
# 5110       -1.845            265.2472        537.9272    0.7057       0.9869
# 5111        1.490            239.0488        539.3200    3.1252       0.9888
# 5112       -0.869            233.1894        540.7564    1.7820       0.7623
# 5113        0.551            118.3418        542.4091    1.6579       0.9898
#
#       air_density  precipitation
# 365        1.2908         0.0151
# 366        1.2745         0.2762
# 367        1.2442         1.0243
# 368        1.2837         0.1739
# 369        1.2872         0.4115
# ...           ...            ...
# 5109       1.2706         0.4975
# 5110       1.2887         0.0885
# 5111       1.2737         0.5344
# 5112       1.2798         0.1649
# 5113       1.2829         0.2462
#
# [4749 rows x 10 columns]

# %%
df_daily['season'] = df_daily.apply(lambda x: season(x['time']), axis=1)
df_daily = df_daily[['time', 'season', 'precipitation', 'temperature', 'irradiance_surface', 
           'irradiance_toa', 'snowfall', 'snow_depth', 'cloud_cover', 'air_density', 'Total Energy Use from Electricity (MW)']]
df_daily
# Out:
#            time  season  precipitation  temperature  irradiance_surface  \
# 365  2004-01-01  winter         0.0151        0.335            311.1307
# 366  2004-01-02  winter         0.2762        3.126            202.3642
# 367  2004-01-03  winter         1.0243        5.863            167.0140
# 368  2004-01-04  winter         0.1739        2.157            183.1127
# 369  2004-01-05  winter         0.4115       -3.564            179.3832
# ...         ...     ...            ...          ...                 ...
# 5109 2016-12-27  winter         0.4975        6.067            202.2915
# 5110 2016-12-28  winter         0.0885       -1.845            265.2472
# 5111 2016-12-29  winter         0.5344        1.490            239.0488
# 5112 2016-12-30  winter         0.1649       -0.869            233.1894
# 5113 2016-12-31  winter         0.2462        0.551            118.3418
#
#       irradiance_toa  snowfall  snow_depth  cloud_cover  air_density  \
# 365         542.9119    0.0608     17.2316       0.9669       1.2908
# 366         544.8137    1.0279     17.2797       0.9959       1.2745
# 367         546.8158    0.6193     17.3078       0.9964       1.2442
# 368         548.9446    0.3873     17.3005       0.9734       1.2837
# 369         551.3384    2.6992     17.3234       0.9688       1.2872
# ...              ...       ...         ...          ...          ...
# 5109        536.8441    0.5069     17.1246       0.8070       1.2706
# 5110        537.9272    0.7057     16.8999       0.9869       1.2887
# 5111        539.3200    3.1252     16.9279       0.9888       1.2737
# 5112        540.7564    1.7820     16.9282       0.7623       1.2798
# 5113        542.4091    1.6579     17.0087       0.9898       1.2829
#
#       Total Energy Use from Electricity (MW)
# 365                                   363449
# 366                                   392163
# 367                                   377787
# 368                                   392135
# 369                                   460254
# ...                                      ...
# 5109                                  349744
# 5110                                  370750
# 5111                                  370212
# 5112                                  368597
# 5113                                  356693
#
# [4749 rows x 11 columns]

# %%
df_daily['season'].value_counts()
# Out:
# spring    1196
# summer    1196
# fall      1183
# winter    1174
# Name: season, dtype: int64

# %% [markdown]
# ## Exploratory Analysis

# %%
plt.figure(figsize=(15,8))
plt.title('energy_consumption')
plt.plot(standardized_df_hourly['dates'], standardized_df_hourly['Total Energy Use from Electricity (MW)'])
plt.xlabel('Date')
plt.show()

# %%
def get_period(df, start_date, end_date, col_name='dates'):
    df_start = df[df[col_name] >= pd.to_datetime(start_date)]
    return df_start[df_start[col_name] <= pd.to_datetime(end_date)]

# %%
start_date = '2016-01-01'
end_date = '2016-12-31'
df_2016 = get_period(standardized_df_hourly, start_date, end_date)
df_2016
# Out:
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64452/3640062300.py:2: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   df_start = df[df[col_name] >= pd.to_datetime(start_date)]
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64452/3640062300.py:3: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   return df_start[df_start[col_name] <= pd.to_datetime(end_date)]
#              dates  hour  season  precipitation  temperature  \
# 113952  2016-01-01     0  winter      -0.414397    -0.944033
# 113953  2016-01-01     1  winter      -0.403831    -0.951792
# 113954  2016-01-01     2  winter      -0.381117    -0.941535
# 113955  2016-01-01     3  winter      -0.346252    -0.922003
# 113956  2016-01-01     4  winter      -0.300822    -0.917722
# ...            ...   ...     ...            ...          ...
# 122731  2016-12-31    19  winter       0.404924    -0.654253
# 122732  2016-12-31    20  winter       0.518499    -0.662815
# 122733  2016-12-31    21  winter       0.764136    -0.687343
# 122734  2016-12-31    22  winter       0.838092    -0.707589
# 122735  2016-12-31    23  winter       0.680144    -0.718203
#
#         irradiance_surface  irradiance_toa  snowfall  snow_depth  cloud_cover  \
# 113952           -0.692273       -0.793046 -0.154734    1.371837    -0.576142
# 113953           -0.692273       -0.793046 -0.124149    1.371712    -0.446466
# 113954           -0.692273       -0.793046 -0.074629    1.371613    -0.089208
# 113955           -0.692273       -0.793046  0.011303    1.371538     0.374383
# 113956           -0.692273       -0.793046  0.114711    1.371501     0.509895
# ...                    ...             ...       ...         ...          ...
# 122731           -0.424961        0.213500  0.978395    1.272506     1.402390
# 122732           -0.571157       -0.186342  1.004611    1.272854     1.392016
# 122733           -0.672567       -0.658109  1.284252    1.273886     1.359273
# 122734           -0.692254       -0.792950  1.456115    1.276186     1.270120
# 122735           -0.692273       -0.793046  1.207059    1.278947     1.090519
#
#         air_density  Total Energy Use from Electricity (MW)
# 113952     0.901531                               -1.186723
# 113953     0.907117                               -1.359357
# 113954     0.905255                               -1.579667
# 113955     0.907117                               -1.643876
# 113956     0.916426                               -1.686938
# ...             ...                                     ...
# 122731     0.287094                               -0.093631
# 122732     0.285232                               -0.325091
# 122733     0.303851                               -0.503108
# 122734     0.328056                               -0.671128
# 122735     0.348537                               -0.903741
#
# [8784 rows x 12 columns]

# %%
start_date = '2015-01-01'
end_date = '2015-12-31'
df_2015 = get_period(standardized_df_hourly, start_date, end_date)
df_2015
# Out:
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64452/3640062300.py:2: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   df_start = df[df[col_name] >= pd.to_datetime(start_date)]
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64452/3640062300.py:3: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   return df_start[df_start[col_name] <= pd.to_datetime(end_date)]
#              dates  hour  season  precipitation  temperature  \
# 105192  2015-01-01     0  winter      -0.406473    -1.348601
# 105193  2015-01-01     1  winter      -0.416510    -1.355201
# 105194  2015-01-01     2  winter      -0.418623    -1.373931
# 105195  2015-01-01     3  winter      -0.412284    -1.396763
# 105196  2015-01-01     4  winter      -0.408058    -1.409607
# ...            ...   ...     ...            ...          ...
# 113947  2015-12-31    19  winter      -0.350478    -0.702862
# 113948  2015-12-31    20  winter      -0.380588    -0.740233
# 113949  2015-12-31    21  winter      -0.405944    -0.822645
# 113950  2015-12-31    22  winter      -0.417566    -0.889805
# 113951  2015-12-31    23  winter      -0.418623    -0.921557
#
#         irradiance_surface  irradiance_toa  snowfall  snow_depth  cloud_cover  \
# 105192           -0.692273       -0.793046 -0.097932    1.322053     1.169297
# 105193           -0.692273       -0.793046 -0.125605    1.322103     0.997801
# 105194           -0.692273       -0.793046 -0.131431    1.322140     0.881417
# 105195           -0.692273       -0.793046 -0.113953    1.322140     0.714459
# 105196           -0.692273       -0.793046 -0.102302    1.322128     0.508274
# ...                    ...             ...       ...         ...          ...
# 113947           -0.097976        0.210611 -0.064434    1.372521     0.031066
# 113948           -0.371372       -0.189117 -0.112497    1.372284    -0.072350
# 113949           -0.638878       -0.659938 -0.144539    1.372135    -0.250979
# 113950           -0.692255       -0.792956 -0.159104    1.372023    -0.478885
# 113951           -0.692273       -0.793046 -0.159104    1.371936    -0.580680
#
#         air_density  Total Energy Use from Electricity (MW)
# 105192     1.417286                               -0.593462
# 105193     1.398667                               -0.779553
# 105194     1.396805                               -0.970642
# 105195     1.406114                               -1.089448
# 105196     1.407976                               -1.129050
# ...             ...                                     ...
# 113947     0.793539                               -0.006737
# 113948     0.812158                               -0.270110
# 113949     0.838225                               -0.559627
# 113950     0.866154                               -0.783782
# 113951     0.886635                               -1.004092
#
# [8760 rows x 12 columns]

# %%
def box_plot(df, by_type='hour'):
    fig = plt.figure()
    ax = df.boxplot(by=by_type, column='Total Energy Use from Electricity (MW)', figsize=(10, 6))
    plt.xlabel(f"{by_type} type")
    plt.ylabel("Total Energy Use from Electricity (MW)")
    ax.tick_params(axis='x', rotation=90)
    plt.show()

# %%
box_plot(df_2016, by_type='season')

# %%
box_plot(df_2015, by_type='season')

# %%
def bar_plot(df, column_type='hour'):
    plt.figure(figsize=(12, 6))
    sns.barplot(x=column_type, y='Total Energy Use from Electricity (MW)', data=df, ci=None, estimator=sum)
    plt.title(f'{column_type}ly energy consumption')
    plt.xlabel(f'{column_type} of the day')
    plt.ylabel('Total Energy Consumption')
    plt.show()

# %%
bar_plot(standardized_df_hourly)
# Out:
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64452/933044428.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=column_type, y='Total Energy Use from Electricity (MW)', data=df, ci=None, estimator=sum)

# %%
bar_plot(df_hourly, column_type='season')
# Out:
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64341/933044428.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=column_type, y='Total Energy Use from Electricity (MW)', data=df, ci=None, estimator=sum)

# %%
df_hourly_test = df_hourly.copy()
df_hourly_test['month'] = pd.to_datetime(df_hourly['dates']).dt.month

# %%
bar_plot(df_hourly_test, column_type='month')
# Out:
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64341/933044428.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=column_type, y='Total Energy Use from Electricity (MW)', data=df, ci=None, estimator=sum)

# %% [markdown]
# Observation:
#
# - January, December, July, August are the four months with highest energy consumption.
# - It can be explained by (Jan, Dec) - coldest months, (July, Aug) - hottest months

# %% [markdown]
# ## Linear Regression/Decision Tree Regressor - ML Model

# %%
input_data = np.array(df_hourly.drop(columns=["dates", "hour", "season", "Total Energy Use from Electricity (MW)"]))
output_data = np.array(df_hourly["Total Energy Use from Electricity (MW)"])

# %%
# 0.3 -> 70% training data and 30% testing data
x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size = 0.3)

# decision tree regressor model
tree = DecisionTreeRegressor().fit(x_train, y_train)
# linear regression model
lr = LinearRegression().fit(x_train, y_train)

# %%
tree_prediction = tree.predict(x_test)
lr_prediction = lr.predict(x_test)

# %%
def plot_result(y_test, y_pred, df=None, model_type="Linear Regression"):
    plt.figure(figsize=(12,7))
    plt.title(f'{model_type} Model')
    plt.xlabel('Days')
    plt.ylabel('Total Energy Use from Electricity (MW)')
    if df is not None:
        plt.plot(df['dates'], y_test, color="blue")
        plt.plot(df['dates'], y_pred, color="red")
    else:
        plt.plot(y_test, color="blue")
        plt.plot(y_pred, color="red")
    plt.show()

# %%
plot_result(y_test=y_test, y_pred=lr_prediction)

# %%
plot_result(y_test, tree_prediction, model_type="Decision Tree Regressor")

# %% [markdown]
# ### Predict 2016 energy consumption

# %%
x_train = np.array(df_hourly[df_hourly['dates'] <= pd.Timestamp(2015, 12, 31)].drop(columns=["dates", "hour", "season", "Total Energy Use from Electricity (MW)"]))
y_train = np.array(df_hourly[df_hourly['dates'] <= pd.Timestamp(2015, 12, 31)]["Total Energy Use from Electricity (MW)"])

x_test = np.array(df_2016.drop(columns=["dates", "hour", "season", "Total Energy Use from Electricity (MW)"]))
y_test = np.array(df_2016["Total Energy Use from Electricity (MW)"])
# Out:
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64341/2594482171.py:1: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   x_train = np.array(df_hourly[df_hourly['dates'] <= pd.Timestamp(2015, 12, 31)].drop(columns=["dates", "hour", "season", "Total Energy Use from Electricity (MW)"]))
# /var/folders/sn/6brth5ks4z1gsf8wqvllhzz00000gn/T/ipykernel_64341/2594482171.py:2: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   y_train = np.array(df_hourly[df_hourly['dates'] <= pd.Timestamp(2015, 12, 31)]["Total Energy Use from Electricity (MW)"])

# %%
print('Training Features Shape (X_train):', x_train.shape)
print('Training Labels Shape (y_train):', y_train.shape)
print('Testing Features Shape (X_test):', x_test.shape)
print('Testing Labels Shape (y_test):', y_test.shape)
# Out:
# Training Features Shape (X_train): (105192, 8)
# Training Labels Shape (y_train): (105192,)
# Testing Features Shape (X_test): (8784, 8)
# Testing Labels Shape (y_test): (8784,)

# %%
# decision tree regressor model
tree = DecisionTreeRegressor().fit(x_train, y_train)
# linear regression model
lr = LinearRegression().fit(x_train, y_train)
# random forest
rf = RandomForestRegressor().fit(x_train, y_train)
# gradient boosting
gb = GradientBoostingRegressor().fit(x_train, y_train)

# %%
tree_pred = tree.predict(x_test)
lr_pred = lr.predict(x_test)
rf_pred = rf.predict(x_test)
gb_pred = gb.predict(x_test)

# %%
models = ['Linear Regression', "Decision Tree Regressor", "Random Forest Regressor", "Gradient Boosting Regressor"]#, "Gradient Boosting Classifier"]
y_pred = [lr_pred, tree_pred, rf_pred, gb_pred]

for i in range(len(models)):
    plot_result(y_test, y_pred[i], df_2016, model_type=models[i])

# %%
for i in range(len(models)):
    mae = mean_absolute_error(y_test, y_pred[i])
    print(f'MAE = {mae} for {models[i]} model')
# Out:
# MAE = 1899.728055508658 for Linear Regression model
# MAE = 2017.858606557377 for Decision Tree Regressor model
# MAE = 1595.0611828324224 for Random Forest Regressor model
# MAE = 1618.9230020627997 for Gradient Boosting Regressor model

# %% [markdown]
# - Best model so far - Random Forest Regressor
# - Further investigation by finding the best **hyper-parameter** for the **Random Forest Regressor**

# %%
param_dict_rfr = {'max_depth' : [1,5],
                  'n_estimators': [20, 50],
                  'criterion' :['absolute_error'] } 
grid_rf = GridSearchCV(rf, param_grid = param_dict_rfr)
grid_rf.fit(x_train, y_train)

# %%
# Print the best hyperparameters
print("Best parameters found: ", grid_rf.best_params_)

# %%
# set up the model with the tunning hyper parameter
# rf_improved = RandomForestRegressor(n_estimators= grid_rf.best_params_['n_estimators'],
#                                criterion = grid_rf.best_params_['criterion'], 
#                                max_depth = grid_rf.best_params_['max_depth'], 
#                                max_features = grid_rf.best_params_['max_features'], 
#                                random_state=42)

# %%
# # train the model
# rf_improved.fit(x_train, y_train)

# # test model
# y_pred = rf_improved.predict(x_test)
# mean_absolute_error(y_test, y_pred)
